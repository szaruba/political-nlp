# %% [markdown]
# With stop-word removal
# -----------------------------

# %%
import sklearn.metrics
# %matplotlib inline

import torch
import re
from torch.utils.data import DataLoader
import random
import time
import helper.sklearn_to_csv
from sklearn import metrics

# %%
COL_OPINION = 0
COL_SPEECH = 8

RUNS = 100
TEST_SPLIT = 0.15
VALID_SPLIT = 0.15
SHUFFLE = True
STRATIFY = True
CLASS_WEIGHTS = True
REMOVE_STOP_WORDS = False
STEMMING = False
LOWERING = False
NO_PUNCTUATION = False

OUT_NAME = f'measures_embeddingbag_01_{TEST_SPLIT}_{VALID_SPLIT}_Shuff{SHUFFLE}_Strat{STRATIFY}_Weigh{CLASS_WEIGHTS}_NoStop{REMOVE_STOP_WORDS}_Stem{STEMMING}_Low{LOWERING}_NoPun{NO_PUNCTUATION}'
PATH_METRICS = f'../results/{OUT_NAME}.csv'
PATH_DATASET = "../protocols/labelled/massnahmen_relevant.csv"
PATH_PERFORMANCE_GRAPH = f'../results/{OUT_NAME}.png'

# %%
label_class_map = {'-': 0, 'o': 1, '+': 2}

# %%
positive_samples = []
negative_samples = []
neutral_samples = []

with open(PATH_DATASET, 'r') as f:
    next(f)
    for line in f:
        col_vals = re.split('\\t', line)
        opinion = col_vals[COL_OPINION]
        sentence = col_vals[COL_SPEECH]
        if opinion == '+':
            positive_samples.append((2, sentence))
        elif opinion == '-':
            negative_samples.append((0, sentence))
        elif opinion == 'o':
            neutral_samples.append((1, sentence))

all_samples = positive_samples + negative_samples + neutral_samples

# %%
def get_train_test_split_proportional(data_tuples, test_split=TEST_SPLIT, shuffle=SHUFFLE):
    positive = [e for e in data_tuples if e[0] == 2]
    negative = [e for e in data_tuples if e[0] == 0]
    neutral = [e for e in data_tuples if e[0] == 1]

    neg_train = int(len(negative) * (1.0-test_split))
    neut_train = int(len(neutral) * (1.0-test_split))
    pos_train = int(len(positive) * (1.0-test_split))

    if shuffle:
        random.shuffle(positive)
        random.shuffle(negative)
        random.shuffle(neutral)
    train_data = positive[:pos_train] + negative[:neg_train] + neutral[:neut_train]
    valid_data = positive[pos_train:] + negative[neg_train:] + neutral[neut_train:]

    return train_data, valid_data, neg_train, neut_train, pos_train

# def get_train_test_split_proportional(data_tuples, ratio=TEST_SPLIT, shuffle=SHUFFLE):
#     pos = positive_samples.copy()
#     neg = negative_samples.copy()
#     neut = neutral_samples.copy()
#     if shuffle:
#         random.shuffle(pos)
#         random.shuffle(neg)
#         random.shuffle(neut)
#     test_samples = [(2,s) for s in pos[:int(ratio*len(pos))]] + \
#             [(0,s) for s in neg[:int(ratio*len(neg))]] + \
#             [(1,s) for s in neut[:int(ratio*len(neut))]]
#     train_samples = [(2,s) for s in pos[int(ratio*len(pos)):]] + \
#             [(0,s) for s in neg[int(ratio*len(neg)):]] + \
#             [(1,s) for s in neut[int(ratio*len(neut)):]]
#     return train_samples, test_samples

def get_train_test_split_even(per_class=50, shuffle=SHUFFLE):
    pos = positive_samples.copy()
    neg = negative_samples.copy()
    neut = neutral_samples.copy()
    if shuffle:
        random.shuffle(pos)
        random.shuffle(neg)
        random.shuffle(neut)
    train_samples = [(2,s) for s in pos[:per_class]] + \
            [(0,s) for s in neg[:per_class]] + \
            [(1,s) for s in neut[:per_class]]
    test_samples = [(2,s) for s in pos[per_class:]] + \
            [(0,s) for s in neg[per_class:]] + \
            [(1,s) for s in neut[per_class:]]
    return train_samples, test_samples

# %% [markdown]
# Prepare data processing pipelines
# ---------------------------------

# %%
from torchtext.data.utils import get_tokenizer
from collections import Counter
from torchtext.vocab import Vocab
import spacy
nlp = spacy.load('de_dep_news_trf')

tokenizer = get_tokenizer('spacy', language='de_dep_news_trf')
counter = Counter()
for sample in all_samples:
    counter.update(tokenizer(sample[1]))
vocab = Vocab(counter, min_freq=0)
text_pipeline = lambda x: [vocab[token] for token in tokenizer(x)]
label_pipeline = lambda x: label_class_map.get(x)

# %%
text_pipeline("Das das ist ein Test.")
# Out:
# [40, 8, 9, 30, 564, 3]

# %% [markdown]
# Generate data batch and iterator
# --------------------------------

# %%
from torch.utils.data import DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def collate_batch(batch):
    class_list, text_list, offsets = [], [], [0]
    for (_class, _text) in batch:
         class_list.append(_class)
         processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
         text_list.append(processed_text)
         offsets.append(processed_text.size(0))
    label_list = torch.tensor(class_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)

# %% [markdown]
# Define the model
# ----------------

# %%
from torch import nn

class TextClassificationModel(nn.Module):

    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.fc = nn.Linear(embed_dim, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()

    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        return self.fc(embedded)

# %% [markdown]
# Initiate an instance
# --------------------

# %%
import time

def train(model, dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 25
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predited_label = model(text, offsets)
        loss = criterion(predited_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predited_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

# %% [markdown]
# Evaluate the model with test dataset
# ------------------------------------

# %%
def evaluate(model, dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    actual_labels = []
    predicted_labels = []

    with torch.no_grad():
        pred_pos = 0
        pred_neg = 0
        pred_neut = 0
        for idx, (label, text, offsets) in enumerate(dataloader):
            actual_labels += label.tolist()
            label_probs = model(text, offsets)
            predicted_label = label_probs.argmax(1)
            predicted_labels += predicted_label.tolist()
            c = Counter(predicted_label.tolist())
            pred_pos += c.get(2, 0)
            pred_neg += c.get(0, 0)
            pred_neut += c.get(1, 0)
            loss = criterion(label_probs, label)
            total_acc += (predicted_label == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count, pred_pos, pred_neg, pred_neut, metrics.classification_report(actual_labels, predicted_labels, output_dict=True)

# %%
# RUN MULTIPLE TIMES
accuracies = []
runs = RUNS
for i in range(runs):
    #train_ds, test_ds = get_train_test_split_even(90, True)
    if STRATIFY:
        train_ds_, test_ds, _, _, _ = get_train_test_split_proportional(all_samples, TEST_SPLIT, SHUFFLE)
        train_ds, valid_ds, neg_train, neut_train, pos_train = get_train_test_split_proportional(train_ds_, VALID_SPLIT, SHUFFLE)
    else:
        raise Exception('only stratify True is allowed')
    num_class = len(label_class_map)
    vocab_size = len(vocab)
    emsize = 64
    model = TextClassificationModel(vocab_size, emsize, num_class).to(device)

    # Hyperparameters
    EPOCHS = 10 # epoch
    LR = 5  # learning rate
    BATCH_SIZE = 16 # batch size for training
    if CLASS_WEIGHTS:
        max_count = max([neg_train, neut_train, pos_train])
        criterion = nn.CrossEntropyLoss(weight=torch.FloatTensor([max_count/float(neg_train), max_count/float(neut_train), max_count/float(pos_train)]))
    else:
        criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=LR)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
    total_accu = None

    train_dataloader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=SHUFFLE, collate_fn=collate_batch)
    valid_dataloader = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=SHUFFLE, collate_fn=collate_batch)
    test_dataloader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=SHUFFLE, collate_fn=collate_batch)

    for epoch in range(1, EPOCHS + 1):
        epoch_start_time = time.time()
        train(model, train_dataloader)
        accu_val, pred_pos, pred_neg, pred_neut, report = evaluate(model, valid_dataloader)
        if total_accu is not None and total_accu > accu_val:
          scheduler.step()
        else:
           total_accu = accu_val
        print('-' * 59)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid accuracy {:8.3f} '.format(epoch, time.time() - epoch_start_time, accu_val))
        print('-' * 59)
    accu_test, pos, neg, neut, classification_report = evaluate(model, test_dataloader)
    helper.sklearn_to_csv.dict_to_csv(classification_report, PATH_METRICS)
    accuracies.append(accu_test)
# Out:
# | epoch   1 |    25/  231 batches | accuracy    0.399
# | epoch   1 |    50/  231 batches | accuracy    0.295
# | epoch   1 |    75/  231 batches | accuracy    0.417
# | epoch   1 |   100/  231 batches | accuracy    0.400
# | epoch   1 |   125/  231 batches | accuracy    0.412
# | epoch   1 |   150/  231 batches | accuracy    0.412
# | epoch   1 |   175/  231 batches | accuracy    0.530
# | epoch   1 |   200/  231 batches | accuracy    0.497
# | epoch   1 |   225/  231 batches | accuracy    0.507
# -----------------------------------------------------------
# | end of epoch   1 | time:  3.18s | valid accuracy    0.521
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.548
# | epoch   2 |    50/  231 batches | accuracy    0.537
# | epoch   2 |    75/  231 batches | accuracy    0.580
# | epoch   2 |   100/  231 batches | accuracy    0.530
# | epoch   2 |   125/  231 batches | accuracy    0.557
# | epoch   2 |   150/  231 batches | accuracy    0.557
# | epoch   2 |   175/  231 batches | accuracy    0.598
# | epoch   2 |   200/  231 batches | accuracy    0.585
# | epoch   2 |   225/  231 batches | accuracy    0.595
# -----------------------------------------------------------
# | end of epoch   2 | time:  2.15s | valid accuracy    0.509
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.627
# | epoch   3 |    50/  231 batches | accuracy    0.688
# | epoch   3 |    75/  231 batches | accuracy    0.603
# | epoch   3 |   100/  231 batches | accuracy    0.615
# | epoch   3 |   125/  231 batches | accuracy    0.647
# | epoch   3 |   150/  231 batches | accuracy    0.675
# | epoch   3 |   175/  231 batches | accuracy    0.657
# | epoch   3 |   200/  231 batches | accuracy    0.665
# | epoch   3 |   225/  231 batches | accuracy    0.635
# -----------------------------------------------------------
# | end of epoch   3 | time:  1.97s | valid accuracy    0.597
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.659
# | epoch   4 |    50/  231 batches | accuracy    0.657
# | epoch   4 |    75/  231 batches | accuracy    0.650
# | epoch   4 |   100/  231 batches | accuracy    0.672
# | epoch   4 |   125/  231 batches | accuracy    0.655
# | epoch   4 |   150/  231 batches | accuracy    0.637
# | epoch   4 |   175/  231 batches | accuracy    0.632
# | epoch   4 |   200/  231 batches | accuracy    0.637
# | epoch   4 |   225/  231 batches | accuracy    0.655
# -----------------------------------------------------------
# | end of epoch   4 | time:  1.78s | valid accuracy    0.610
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.714
# | epoch   5 |    50/  231 batches | accuracy    0.657
# | epoch   5 |    75/  231 batches | accuracy    0.637
# | epoch   5 |   100/  231 batches | accuracy    0.677
# | epoch   5 |   125/  231 batches | accuracy    0.635
# | epoch   5 |   150/  231 batches | accuracy    0.642
# | epoch   5 |   175/  231 batches | accuracy    0.685
# | epoch   5 |   200/  231 batches | accuracy    0.625
# | epoch   5 |   225/  231 batches | accuracy    0.630
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.47s | valid accuracy    0.610
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.661
# | epoch   6 |    50/  231 batches | accuracy    0.670
# | epoch   6 |    75/  231 batches | accuracy    0.657
# | epoch   6 |   100/  231 batches | accuracy    0.670
# | epoch   6 |   125/  231 batches | accuracy    0.627
# | epoch   6 |   150/  231 batches | accuracy    0.695
# | epoch   6 |   175/  231 batches | accuracy    0.662
# | epoch   6 |   200/  231 batches | accuracy    0.680
# | epoch   6 |   225/  231 batches | accuracy    0.657
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.68s | valid accuracy    0.626
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.688
# | epoch   7 |    50/  231 batches | accuracy    0.642
# | epoch   7 |    75/  231 batches | accuracy    0.660
# | epoch   7 |   100/  231 batches | accuracy    0.682
# | epoch   7 |   125/  231 batches | accuracy    0.650
# | epoch   7 |   150/  231 batches | accuracy    0.677
# | epoch   7 |   175/  231 batches | accuracy    0.698
# | epoch   7 |   200/  231 batches | accuracy    0.715
# | epoch   7 |   225/  231 batches | accuracy    0.688
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.83s | valid accuracy    0.618
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.688
# | epoch   8 |    50/  231 batches | accuracy    0.703
# | epoch   8 |    75/  231 batches | accuracy    0.685
# | epoch   8 |   100/  231 batches | accuracy    0.667
# | epoch   8 |   125/  231 batches | accuracy    0.728
# | epoch   8 |   150/  231 batches | accuracy    0.642
# | epoch   8 |   175/  231 batches | accuracy    0.635
# | epoch   8 |   200/  231 batches | accuracy    0.698
# | epoch   8 |   225/  231 batches | accuracy    0.660
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.75s | valid accuracy    0.626
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.690
# | epoch   9 |    50/  231 batches | accuracy    0.672
# | epoch   9 |    75/  231 batches | accuracy    0.677
# | epoch   9 |   100/  231 batches | accuracy    0.700
# | epoch   9 |   125/  231 batches | accuracy    0.682
# | epoch   9 |   150/  231 batches | accuracy    0.700
# | epoch   9 |   175/  231 batches | accuracy    0.685
# | epoch   9 |   200/  231 batches | accuracy    0.623
# | epoch   9 |   225/  231 batches | accuracy    0.705
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.64s | valid accuracy    0.624
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.656
# | epoch  10 |    50/  231 batches | accuracy    0.715
# | epoch  10 |    75/  231 batches | accuracy    0.693
# | epoch  10 |   100/  231 batches | accuracy    0.693
# | epoch  10 |   125/  231 batches | accuracy    0.713
# | epoch  10 |   150/  231 batches | accuracy    0.685
# | epoch  10 |   175/  231 batches | accuracy    0.670
# | epoch  10 |   200/  231 batches | accuracy    0.662
# | epoch  10 |   225/  231 batches | accuracy    0.645
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.65s | valid accuracy    0.624
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.438
# | epoch   1 |    50/  231 batches | accuracy    0.372
# | epoch   1 |    75/  231 batches | accuracy    0.407
# | epoch   1 |   100/  231 batches | accuracy    0.395
# | epoch   1 |   125/  231 batches | accuracy    0.393
# | epoch   1 |   150/  231 batches | accuracy    0.422
# | epoch   1 |   175/  231 batches | accuracy    0.515
# | epoch   1 |   200/  231 batches | accuracy    0.463
# | epoch   1 |   225/  231 batches | accuracy    0.455
# -----------------------------------------------------------
# | end of epoch   1 | time:  2.75s | valid accuracy    0.531
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.565
# | epoch   2 |    50/  231 batches | accuracy    0.562
# | epoch   2 |    75/  231 batches | accuracy    0.595
# | epoch   2 |   100/  231 batches | accuracy    0.540
# | epoch   2 |   125/  231 batches | accuracy    0.552
# | epoch   2 |   150/  231 batches | accuracy    0.545
# | epoch   2 |   175/  231 batches | accuracy    0.578
# | epoch   2 |   200/  231 batches | accuracy    0.600
# | epoch   2 |   225/  231 batches | accuracy    0.525
# -----------------------------------------------------------
# | end of epoch   2 | time:  3.66s | valid accuracy    0.589
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.608
# | epoch   3 |    50/  231 batches | accuracy    0.608
# | epoch   3 |    75/  231 batches | accuracy    0.652
# | epoch   3 |   100/  231 batches | accuracy    0.620
# | epoch   3 |   125/  231 batches | accuracy    0.615
# | epoch   3 |   150/  231 batches | accuracy    0.590
# | epoch   3 |   175/  231 batches | accuracy    0.655
# | epoch   3 |   200/  231 batches | accuracy    0.667
# | epoch   3 |   225/  231 batches | accuracy    0.650
# -----------------------------------------------------------
# | end of epoch   3 | time:  1.94s | valid accuracy    0.606
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.678
# | epoch   4 |    50/  231 batches | accuracy    0.645
# | epoch   4 |    75/  231 batches | accuracy    0.680
# | epoch   4 |   100/  231 batches | accuracy    0.672
# | epoch   4 |   125/  231 batches | accuracy    0.660
# | epoch   4 |   150/  231 batches | accuracy    0.690
# | epoch   4 |   175/  231 batches | accuracy    0.675
# | epoch   4 |   200/  231 batches | accuracy    0.627
# | epoch   4 |   225/  231 batches | accuracy    0.675
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.01s | valid accuracy    0.567
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.704
# | epoch   5 |    50/  231 batches | accuracy    0.743
# | epoch   5 |    75/  231 batches | accuracy    0.767
# | epoch   5 |   100/  231 batches | accuracy    0.740
# | epoch   5 |   125/  231 batches | accuracy    0.723
# | epoch   5 |   150/  231 batches | accuracy    0.710
# | epoch   5 |   175/  231 batches | accuracy    0.748
# | epoch   5 |   200/  231 batches | accuracy    0.723
# | epoch   5 |   225/  231 batches | accuracy    0.688
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.01s | valid accuracy    0.623
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.733
# | epoch   6 |    50/  231 batches | accuracy    0.738
# | epoch   6 |    75/  231 batches | accuracy    0.740
# | epoch   6 |   100/  231 batches | accuracy    0.733
# | epoch   6 |   125/  231 batches | accuracy    0.735
# | epoch   6 |   150/  231 batches | accuracy    0.782
# | epoch   6 |   175/  231 batches | accuracy    0.733
# | epoch   6 |   200/  231 batches | accuracy    0.718
# | epoch   6 |   225/  231 batches | accuracy    0.720
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.97s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.745
# | epoch   7 |    50/  231 batches | accuracy    0.703
# | epoch   7 |    75/  231 batches | accuracy    0.757
# | epoch   7 |   100/  231 batches | accuracy    0.730
# | epoch   7 |   125/  231 batches | accuracy    0.738
# | epoch   7 |   150/  231 batches | accuracy    0.728
# | epoch   7 |   175/  231 batches | accuracy    0.765
# | epoch   7 |   200/  231 batches | accuracy    0.740
# | epoch   7 |   225/  231 batches | accuracy    0.748
# -----------------------------------------------------------
# | end of epoch   7 | time:  2.01s | valid accuracy    0.624
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.726
# | epoch   8 |    50/  231 batches | accuracy    0.770
# | epoch   8 |    75/  231 batches | accuracy    0.770
# | epoch   8 |   100/  231 batches | accuracy    0.748
# | epoch   8 |   125/  231 batches | accuracy    0.770
# | epoch   8 |   150/  231 batches | accuracy    0.782
# | epoch   8 |   175/  231 batches | accuracy    0.730
# | epoch   8 |   200/  231 batches | accuracy    0.752
# | epoch   8 |   225/  231 batches | accuracy    0.740
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.79s | valid accuracy    0.632
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.750
# | epoch   9 |    50/  231 batches | accuracy    0.760
# | epoch   9 |    75/  231 batches | accuracy    0.762
# | epoch   9 |   100/  231 batches | accuracy    0.730
# | epoch   9 |   125/  231 batches | accuracy    0.733
# | epoch   9 |   150/  231 batches | accuracy    0.745
# | epoch   9 |   175/  231 batches | accuracy    0.743
# | epoch   9 |   200/  231 batches | accuracy    0.748
# | epoch   9 |   225/  231 batches | accuracy    0.743
# -----------------------------------------------------------
# | end of epoch   9 | time:  2.01s | valid accuracy    0.617
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.726
# | epoch  10 |    50/  231 batches | accuracy    0.762
# | epoch  10 |    75/  231 batches | accuracy    0.750
# | epoch  10 |   100/  231 batches | accuracy    0.718
# | epoch  10 |   125/  231 batches | accuracy    0.802
# | epoch  10 |   150/  231 batches | accuracy    0.755
# | epoch  10 |   175/  231 batches | accuracy    0.770
# | epoch  10 |   200/  231 batches | accuracy    0.740
# | epoch  10 |   225/  231 batches | accuracy    0.713
# -----------------------------------------------------------
# | end of epoch  10 | time:  2.67s | valid accuracy    0.618
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.368
# | epoch   1 |    50/  231 batches | accuracy    0.422
# | epoch   1 |    75/  231 batches | accuracy    0.343
# | epoch   1 |   100/  231 batches | accuracy    0.365
# | epoch   1 |   125/  231 batches | accuracy    0.465
# | epoch   1 |   150/  231 batches | accuracy    0.427
# | epoch   1 |   175/  231 batches | accuracy    0.510
# | epoch   1 |   200/  231 batches | accuracy    0.485
# | epoch   1 |   225/  231 batches | accuracy    0.482
# -----------------------------------------------------------
# | end of epoch   1 | time:  2.19s | valid accuracy    0.360
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.572
# | epoch   2 |    50/  231 batches | accuracy    0.562
# | epoch   2 |    75/  231 batches | accuracy    0.557
# | epoch   2 |   100/  231 batches | accuracy    0.583
# | epoch   2 |   125/  231 batches | accuracy    0.550
# | epoch   2 |   150/  231 batches | accuracy    0.547
# | epoch   2 |   175/  231 batches | accuracy    0.590
# | epoch   2 |   200/  231 batches | accuracy    0.585
# | epoch   2 |   225/  231 batches | accuracy    0.557
# -----------------------------------------------------------
# | end of epoch   2 | time:  2.06s | valid accuracy    0.551
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.615
# | epoch   3 |    50/  231 batches | accuracy    0.630
# | epoch   3 |    75/  231 batches | accuracy    0.630
# | epoch   3 |   100/  231 batches | accuracy    0.642
# | epoch   3 |   125/  231 batches | accuracy    0.627
# | epoch   3 |   150/  231 batches | accuracy    0.642
# | epoch   3 |   175/  231 batches | accuracy    0.623
# | epoch   3 |   200/  231 batches | accuracy    0.637
# | epoch   3 |   225/  231 batches | accuracy    0.608
# -----------------------------------------------------------
# | end of epoch   3 | time:  2.30s | valid accuracy    0.575
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.666
# | epoch   4 |    50/  231 batches | accuracy    0.700
# | epoch   4 |    75/  231 batches | accuracy    0.670
# | epoch   4 |   100/  231 batches | accuracy    0.713
# | epoch   4 |   125/  231 batches | accuracy    0.693
# | epoch   4 |   150/  231 batches | accuracy    0.667
# | epoch   4 |   175/  231 batches | accuracy    0.677
# | epoch   4 |   200/  231 batches | accuracy    0.690
# | epoch   4 |   225/  231 batches | accuracy    0.635
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.08s | valid accuracy    0.603
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.736
# | epoch   5 |    50/  231 batches | accuracy    0.713
# | epoch   5 |    75/  231 batches | accuracy    0.685
# | epoch   5 |   100/  231 batches | accuracy    0.713
# | epoch   5 |   125/  231 batches | accuracy    0.698
# | epoch   5 |   150/  231 batches | accuracy    0.700
# | epoch   5 |   175/  231 batches | accuracy    0.708
# | epoch   5 |   200/  231 batches | accuracy    0.708
# | epoch   5 |   225/  231 batches | accuracy    0.703
# -----------------------------------------------------------
# | end of epoch   5 | time:  1.93s | valid accuracy    0.552
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.748
# | epoch   6 |    50/  231 batches | accuracy    0.765
# | epoch   6 |    75/  231 batches | accuracy    0.782
# | epoch   6 |   100/  231 batches | accuracy    0.785
# | epoch   6 |   125/  231 batches | accuracy    0.765
# | epoch   6 |   150/  231 batches | accuracy    0.745
# | epoch   6 |   175/  231 batches | accuracy    0.765
# | epoch   6 |   200/  231 batches | accuracy    0.790
# | epoch   6 |   225/  231 batches | accuracy    0.782
# -----------------------------------------------------------
# | end of epoch   6 | time:  2.70s | valid accuracy    0.606
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.757
# | epoch   7 |    50/  231 batches | accuracy    0.802
# | epoch   7 |    75/  231 batches | accuracy    0.780
# | epoch   7 |   100/  231 batches | accuracy    0.762
# | epoch   7 |   125/  231 batches | accuracy    0.795
# | epoch   7 |   150/  231 batches | accuracy    0.750
# | epoch   7 |   175/  231 batches | accuracy    0.777
# | epoch   7 |   200/  231 batches | accuracy    0.782
# | epoch   7 |   225/  231 batches | accuracy    0.775
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.54s | valid accuracy    0.595
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.784
# | epoch   8 |    50/  231 batches | accuracy    0.792
# | epoch   8 |    75/  231 batches | accuracy    0.750
# | epoch   8 |   100/  231 batches | accuracy    0.780
# | epoch   8 |   125/  231 batches | accuracy    0.775
# | epoch   8 |   150/  231 batches | accuracy    0.777
# | epoch   8 |   175/  231 batches | accuracy    0.775
# | epoch   8 |   200/  231 batches | accuracy    0.782
# | epoch   8 |   225/  231 batches | accuracy    0.785
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.89s | valid accuracy    0.609
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.786
# | epoch   9 |    50/  231 batches | accuracy    0.795
# | epoch   9 |    75/  231 batches | accuracy    0.787
# | epoch   9 |   100/  231 batches | accuracy    0.797
# | epoch   9 |   125/  231 batches | accuracy    0.775
# | epoch   9 |   150/  231 batches | accuracy    0.785
# | epoch   9 |   175/  231 batches | accuracy    0.772
# | epoch   9 |   200/  231 batches | accuracy    0.777
# | epoch   9 |   225/  231 batches | accuracy    0.765
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.85s | valid accuracy    0.606
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.791
# | epoch  10 |    50/  231 batches | accuracy    0.800
# | epoch  10 |    75/  231 batches | accuracy    0.800
# | epoch  10 |   100/  231 batches | accuracy    0.780
# | epoch  10 |   125/  231 batches | accuracy    0.782
# | epoch  10 |   150/  231 batches | accuracy    0.785
# | epoch  10 |   175/  231 batches | accuracy    0.775
# | epoch  10 |   200/  231 batches | accuracy    0.782
# | epoch  10 |   225/  231 batches | accuracy    0.760
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.85s | valid accuracy    0.606
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.279
# | epoch   1 |    50/  231 batches | accuracy    0.400
# | epoch   1 |    75/  231 batches | accuracy    0.323
# | epoch   1 |   100/  231 batches | accuracy    0.388
# | epoch   1 |   125/  231 batches | accuracy    0.417
# | epoch   1 |   150/  231 batches | accuracy    0.470
# | epoch   1 |   175/  231 batches | accuracy    0.537
# | epoch   1 |   200/  231 batches | accuracy    0.468
# | epoch   1 |   225/  231 batches | accuracy    0.547
# -----------------------------------------------------------
# | end of epoch   1 | time:  1.67s | valid accuracy    0.506
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.519
# | epoch   2 |    50/  231 batches | accuracy    0.605
# | epoch   2 |    75/  231 batches | accuracy    0.530
# | epoch   2 |   100/  231 batches | accuracy    0.520
# | epoch   2 |   125/  231 batches | accuracy    0.570
# | epoch   2 |   150/  231 batches | accuracy    0.632
# | epoch   2 |   175/  231 batches | accuracy    0.585
# | epoch   2 |   200/  231 batches | accuracy    0.605
# | epoch   2 |   225/  231 batches | accuracy    0.588
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.98s | valid accuracy    0.567
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.637
# | epoch   3 |    50/  231 batches | accuracy    0.690
# | epoch   3 |    75/  231 batches | accuracy    0.642
# | epoch   3 |   100/  231 batches | accuracy    0.637
# | epoch   3 |   125/  231 batches | accuracy    0.623
# | epoch   3 |   150/  231 batches | accuracy    0.620
# | epoch   3 |   175/  231 batches | accuracy    0.575
# | epoch   3 |   200/  231 batches | accuracy    0.625
# | epoch   3 |   225/  231 batches | accuracy    0.613
# -----------------------------------------------------------
# | end of epoch   3 | time:  2.16s | valid accuracy    0.606
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.647
# | epoch   4 |    50/  231 batches | accuracy    0.682
# | epoch   4 |    75/  231 batches | accuracy    0.627
# | epoch   4 |   100/  231 batches | accuracy    0.670
# | epoch   4 |   125/  231 batches | accuracy    0.670
# | epoch   4 |   150/  231 batches | accuracy    0.693
# | epoch   4 |   175/  231 batches | accuracy    0.675
# | epoch   4 |   200/  231 batches | accuracy    0.685
# | epoch   4 |   225/  231 batches | accuracy    0.685
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.33s | valid accuracy    0.638
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.683
# | epoch   5 |    50/  231 batches | accuracy    0.700
# | epoch   5 |    75/  231 batches | accuracy    0.703
# | epoch   5 |   100/  231 batches | accuracy    0.725
# | epoch   5 |   125/  231 batches | accuracy    0.720
# | epoch   5 |   150/  231 batches | accuracy    0.703
# | epoch   5 |   175/  231 batches | accuracy    0.682
# | epoch   5 |   200/  231 batches | accuracy    0.690
# | epoch   5 |   225/  231 batches | accuracy    0.710
# -----------------------------------------------------------
# | end of epoch   5 | time:  1.84s | valid accuracy    0.598
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.740
# | epoch   6 |    50/  231 batches | accuracy    0.765
# | epoch   6 |    75/  231 batches | accuracy    0.760
# | epoch   6 |   100/  231 batches | accuracy    0.750
# | epoch   6 |   125/  231 batches | accuracy    0.767
# | epoch   6 |   150/  231 batches | accuracy    0.755
# | epoch   6 |   175/  231 batches | accuracy    0.730
# | epoch   6 |   200/  231 batches | accuracy    0.762
# | epoch   6 |   225/  231 batches | accuracy    0.760
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.63s | valid accuracy    0.633
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.772
# | epoch   7 |    50/  231 batches | accuracy    0.750
# | epoch   7 |    75/  231 batches | accuracy    0.752
# | epoch   7 |   100/  231 batches | accuracy    0.777
# | epoch   7 |   125/  231 batches | accuracy    0.765
# | epoch   7 |   150/  231 batches | accuracy    0.733
# | epoch   7 |   175/  231 batches | accuracy    0.760
# | epoch   7 |   200/  231 batches | accuracy    0.762
# | epoch   7 |   225/  231 batches | accuracy    0.780
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.49s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.769
# | epoch   8 |    50/  231 batches | accuracy    0.767
# | epoch   8 |    75/  231 batches | accuracy    0.755
# | epoch   8 |   100/  231 batches | accuracy    0.775
# | epoch   8 |   125/  231 batches | accuracy    0.730
# | epoch   8 |   150/  231 batches | accuracy    0.743
# | epoch   8 |   175/  231 batches | accuracy    0.770
# | epoch   8 |   200/  231 batches | accuracy    0.762
# | epoch   8 |   225/  231 batches | accuracy    0.790
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.46s | valid accuracy    0.629
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.772
# | epoch   9 |    50/  231 batches | accuracy    0.777
# | epoch   9 |    75/  231 batches | accuracy    0.733
# | epoch   9 |   100/  231 batches | accuracy    0.752
# | epoch   9 |   125/  231 batches | accuracy    0.790
# | epoch   9 |   150/  231 batches | accuracy    0.762
# | epoch   9 |   175/  231 batches | accuracy    0.792
# | epoch   9 |   200/  231 batches | accuracy    0.745
# | epoch   9 |   225/  231 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.64s | valid accuracy    0.629
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.779
# | epoch  10 |    50/  231 batches | accuracy    0.757
# | epoch  10 |    75/  231 batches | accuracy    0.740
# | epoch  10 |   100/  231 batches | accuracy    0.762
# | epoch  10 |   125/  231 batches | accuracy    0.743
# | epoch  10 |   150/  231 batches | accuracy    0.762
# | epoch  10 |   175/  231 batches | accuracy    0.767
# | epoch  10 |   200/  231 batches | accuracy    0.785
# | epoch  10 |   225/  231 batches | accuracy    0.782
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.56s | valid accuracy    0.629
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.274
# | epoch   1 |    50/  231 batches | accuracy    0.388
# | epoch   1 |    75/  231 batches | accuracy    0.405
# | epoch   1 |   100/  231 batches | accuracy    0.470
# | epoch   1 |   125/  231 batches | accuracy    0.443
# | epoch   1 |   150/  231 batches | accuracy    0.460
# | epoch   1 |   175/  231 batches | accuracy    0.465
# | epoch   1 |   200/  231 batches | accuracy    0.527
# | epoch   1 |   225/  231 batches | accuracy    0.510
# -----------------------------------------------------------
# | end of epoch   1 | time:  1.54s | valid accuracy    0.512
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.543
# | epoch   2 |    50/  231 batches | accuracy    0.562
# | epoch   2 |    75/  231 batches | accuracy    0.532
# | epoch   2 |   100/  231 batches | accuracy    0.618
# | epoch   2 |   125/  231 batches | accuracy    0.595
# | epoch   2 |   150/  231 batches | accuracy    0.542
# | epoch   2 |   175/  231 batches | accuracy    0.575
# | epoch   2 |   200/  231 batches | accuracy    0.565
# | epoch   2 |   225/  231 batches | accuracy    0.568
# -----------------------------------------------------------
# | end of epoch   2 | time:  2.76s | valid accuracy    0.498
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.639
# | epoch   3 |    50/  231 batches | accuracy    0.657
# | epoch   3 |    75/  231 batches | accuracy    0.657
# | epoch   3 |   100/  231 batches | accuracy    0.642
# | epoch   3 |   125/  231 batches | accuracy    0.647
# | epoch   3 |   150/  231 batches | accuracy    0.650
# | epoch   3 |   175/  231 batches | accuracy    0.630
# | epoch   3 |   200/  231 batches | accuracy    0.677
# | epoch   3 |   225/  231 batches | accuracy    0.647
# -----------------------------------------------------------
# | end of epoch   3 | time:  2.06s | valid accuracy    0.574
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.678
# | epoch   4 |    50/  231 batches | accuracy    0.703
# | epoch   4 |    75/  231 batches | accuracy    0.608
# | epoch   4 |   100/  231 batches | accuracy    0.660
# | epoch   4 |   125/  231 batches | accuracy    0.640
# | epoch   4 |   150/  231 batches | accuracy    0.670
# | epoch   4 |   175/  231 batches | accuracy    0.645
# | epoch   4 |   200/  231 batches | accuracy    0.642
# | epoch   4 |   225/  231 batches | accuracy    0.660
# -----------------------------------------------------------
# | end of epoch   4 | time:  1.94s | valid accuracy    0.577
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.659
# | epoch   5 |    50/  231 batches | accuracy    0.677
# | epoch   5 |    75/  231 batches | accuracy    0.680
# | epoch   5 |   100/  231 batches | accuracy    0.637
# | epoch   5 |   125/  231 batches | accuracy    0.642
# | epoch   5 |   150/  231 batches | accuracy    0.703
# | epoch   5 |   175/  231 batches | accuracy    0.682
# | epoch   5 |   200/  231 batches | accuracy    0.647
# | epoch   5 |   225/  231 batches | accuracy    0.670
# -----------------------------------------------------------
# | end of epoch   5 | time:  1.68s | valid accuracy    0.583
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.675
# | epoch   6 |    50/  231 batches | accuracy    0.680
# | epoch   6 |    75/  231 batches | accuracy    0.695
# | epoch   6 |   100/  231 batches | accuracy    0.677
# | epoch   6 |   125/  231 batches | accuracy    0.677
# | epoch   6 |   150/  231 batches | accuracy    0.672
# | epoch   6 |   175/  231 batches | accuracy    0.632
# | epoch   6 |   200/  231 batches | accuracy    0.700
# | epoch   6 |   225/  231 batches | accuracy    0.660
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.67s | valid accuracy    0.584
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.663
# | epoch   7 |    50/  231 batches | accuracy    0.675
# | epoch   7 |    75/  231 batches | accuracy    0.675
# | epoch   7 |   100/  231 batches | accuracy    0.695
# | epoch   7 |   125/  231 batches | accuracy    0.682
# | epoch   7 |   150/  231 batches | accuracy    0.733
# | epoch   7 |   175/  231 batches | accuracy    0.660
# | epoch   7 |   200/  231 batches | accuracy    0.675
# | epoch   7 |   225/  231 batches | accuracy    0.675
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.64s | valid accuracy    0.577
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.700
# | epoch   8 |    50/  231 batches | accuracy    0.672
# | epoch   8 |    75/  231 batches | accuracy    0.708
# | epoch   8 |   100/  231 batches | accuracy    0.693
# | epoch   8 |   125/  231 batches | accuracy    0.670
# | epoch   8 |   150/  231 batches | accuracy    0.695
# | epoch   8 |   175/  231 batches | accuracy    0.705
# | epoch   8 |   200/  231 batches | accuracy    0.675
# | epoch   8 |   225/  231 batches | accuracy    0.672
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.74s | valid accuracy    0.587
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.714
# | epoch   9 |    50/  231 batches | accuracy    0.718
# | epoch   9 |    75/  231 batches | accuracy    0.685
# | epoch   9 |   100/  231 batches | accuracy    0.672
# | epoch   9 |   125/  231 batches | accuracy    0.667
# | epoch   9 |   150/  231 batches | accuracy    0.685
# | epoch   9 |   175/  231 batches | accuracy    0.672
# | epoch   9 |   200/  231 batches | accuracy    0.675
# | epoch   9 |   225/  231 batches | accuracy    0.682
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.67s | valid accuracy    0.590
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.704
# | epoch  10 |    50/  231 batches | accuracy    0.682
# | epoch  10 |    75/  231 batches | accuracy    0.708
# | epoch  10 |   100/  231 batches | accuracy    0.703
# | epoch  10 |   125/  231 batches | accuracy    0.665
# | epoch  10 |   150/  231 batches | accuracy    0.667
# | epoch  10 |   175/  231 batches | accuracy    0.708
# | epoch  10 |   200/  231 batches | accuracy    0.675
# | epoch  10 |   225/  231 batches | accuracy    0.688
# -----------------------------------------------------------
# | end of epoch  10 | time:  2.06s | valid accuracy    0.583
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.327
# | epoch   1 |    50/  231 batches | accuracy    0.383
# | epoch   1 |    75/  231 batches | accuracy    0.367
# | epoch   1 |   100/  231 batches | accuracy    0.427
# | epoch   1 |   125/  231 batches | accuracy    0.360
# | epoch   1 |   150/  231 batches | accuracy    0.420
# | epoch   1 |   175/  231 batches | accuracy    0.477
# | epoch   1 |   200/  231 batches | accuracy    0.502
# | epoch   1 |   225/  231 batches | accuracy    0.482
# -----------------------------------------------------------
# | end of epoch   1 | time:  1.99s | valid accuracy    0.543
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.498
# | epoch   2 |    50/  231 batches | accuracy    0.542
# | epoch   2 |    75/  231 batches | accuracy    0.578
# | epoch   2 |   100/  231 batches | accuracy    0.578
# | epoch   2 |   125/  231 batches | accuracy    0.583
# | epoch   2 |   150/  231 batches | accuracy    0.555
# | epoch   2 |   175/  231 batches | accuracy    0.585
# | epoch   2 |   200/  231 batches | accuracy    0.610
# | epoch   2 |   225/  231 batches | accuracy    0.565
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.72s | valid accuracy    0.598
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.582
# | epoch   3 |    50/  231 batches | accuracy    0.630
# | epoch   3 |    75/  231 batches | accuracy    0.623
# | epoch   3 |   100/  231 batches | accuracy    0.630
# | epoch   3 |   125/  231 batches | accuracy    0.623
# | epoch   3 |   150/  231 batches | accuracy    0.667
# | epoch   3 |   175/  231 batches | accuracy    0.627
# | epoch   3 |   200/  231 batches | accuracy    0.605
# | epoch   3 |   225/  231 batches | accuracy    0.642
# -----------------------------------------------------------
# | end of epoch   3 | time:  1.94s | valid accuracy    0.620
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.690
# | epoch   4 |    50/  231 batches | accuracy    0.688
# | epoch   4 |    75/  231 batches | accuracy    0.690
# | epoch   4 |   100/  231 batches | accuracy    0.640
# | epoch   4 |   125/  231 batches | accuracy    0.625
# | epoch   4 |   150/  231 batches | accuracy    0.662
# | epoch   4 |   175/  231 batches | accuracy    0.667
# | epoch   4 |   200/  231 batches | accuracy    0.675
# | epoch   4 |   225/  231 batches | accuracy    0.677
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.43s | valid accuracy    0.607
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.726
# | epoch   5 |    50/  231 batches | accuracy    0.745
# | epoch   5 |    75/  231 batches | accuracy    0.733
# | epoch   5 |   100/  231 batches | accuracy    0.715
# | epoch   5 |   125/  231 batches | accuracy    0.710
# | epoch   5 |   150/  231 batches | accuracy    0.705
# | epoch   5 |   175/  231 batches | accuracy    0.728
# | epoch   5 |   200/  231 batches | accuracy    0.695
# | epoch   5 |   225/  231 batches | accuracy    0.700
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.79s | valid accuracy    0.646
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.716
# | epoch   6 |    50/  231 batches | accuracy    0.748
# | epoch   6 |    75/  231 batches | accuracy    0.730
# | epoch   6 |   100/  231 batches | accuracy    0.745
# | epoch   6 |   125/  231 batches | accuracy    0.720
# | epoch   6 |   150/  231 batches | accuracy    0.740
# | epoch   6 |   175/  231 batches | accuracy    0.750
# | epoch   6 |   200/  231 batches | accuracy    0.703
# | epoch   6 |   225/  231 batches | accuracy    0.698
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.72s | valid accuracy    0.641
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.707
# | epoch   7 |    50/  231 batches | accuracy    0.782
# | epoch   7 |    75/  231 batches | accuracy    0.728
# | epoch   7 |   100/  231 batches | accuracy    0.762
# | epoch   7 |   125/  231 batches | accuracy    0.755
# | epoch   7 |   150/  231 batches | accuracy    0.698
# | epoch   7 |   175/  231 batches | accuracy    0.705
# | epoch   7 |   200/  231 batches | accuracy    0.725
# | epoch   7 |   225/  231 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.66s | valid accuracy    0.644
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.740
# | epoch   8 |    50/  231 batches | accuracy    0.743
# | epoch   8 |    75/  231 batches | accuracy    0.738
# | epoch   8 |   100/  231 batches | accuracy    0.735
# | epoch   8 |   125/  231 batches | accuracy    0.733
# | epoch   8 |   150/  231 batches | accuracy    0.733
# | epoch   8 |   175/  231 batches | accuracy    0.728
# | epoch   8 |   200/  231 batches | accuracy    0.715
# | epoch   8 |   225/  231 batches | accuracy    0.755
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.97s | valid accuracy    0.643
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.762
# | epoch   9 |    50/  231 batches | accuracy    0.703
# | epoch   9 |    75/  231 batches | accuracy    0.755
# | epoch   9 |   100/  231 batches | accuracy    0.725
# | epoch   9 |   125/  231 batches | accuracy    0.755
# | epoch   9 |   150/  231 batches | accuracy    0.740
# | epoch   9 |   175/  231 batches | accuracy    0.725
# | epoch   9 |   200/  231 batches | accuracy    0.740
# | epoch   9 |   225/  231 batches | accuracy    0.723
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.61s | valid accuracy    0.643
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.752
# | epoch  10 |    50/  231 batches | accuracy    0.688
# | epoch  10 |    75/  231 batches | accuracy    0.780
# | epoch  10 |   100/  231 batches | accuracy    0.748
# | epoch  10 |   125/  231 batches | accuracy    0.745
# | epoch  10 |   150/  231 batches | accuracy    0.735
# | epoch  10 |   175/  231 batches | accuracy    0.750
# | epoch  10 |   200/  231 batches | accuracy    0.730
# | epoch  10 |   225/  231 batches | accuracy    0.718
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.68s | valid accuracy    0.643
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.257
# | epoch   1 |    50/  231 batches | accuracy    0.362
# | epoch   1 |    75/  231 batches | accuracy    0.410
# | epoch   1 |   100/  231 batches | accuracy    0.460
# | epoch   1 |   125/  231 batches | accuracy    0.400
# | epoch   1 |   150/  231 batches | accuracy    0.480
# | epoch   1 |   175/  231 batches | accuracy    0.453
# | epoch   1 |   200/  231 batches | accuracy    0.495
# | epoch   1 |   225/  231 batches | accuracy    0.505
# -----------------------------------------------------------
# | end of epoch   1 | time:  1.73s | valid accuracy    0.535
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.534
# | epoch   2 |    50/  231 batches | accuracy    0.550
# | epoch   2 |    75/  231 batches | accuracy    0.570
# | epoch   2 |   100/  231 batches | accuracy    0.593
# | epoch   2 |   125/  231 batches | accuracy    0.522
# | epoch   2 |   150/  231 batches | accuracy    0.537
# | epoch   2 |   175/  231 batches | accuracy    0.530
# | epoch   2 |   200/  231 batches | accuracy    0.603
# | epoch   2 |   225/  231 batches | accuracy    0.560
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.79s | valid accuracy    0.586
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.615
# | epoch   3 |    50/  231 batches | accuracy    0.642
# | epoch   3 |    75/  231 batches | accuracy    0.662
# | epoch   3 |   100/  231 batches | accuracy    0.623
# | epoch   3 |   125/  231 batches | accuracy    0.605
# | epoch   3 |   150/  231 batches | accuracy    0.608
# | epoch   3 |   175/  231 batches | accuracy    0.665
# | epoch   3 |   200/  231 batches | accuracy    0.610
# | epoch   3 |   225/  231 batches | accuracy    0.610
# -----------------------------------------------------------
# | end of epoch   3 | time:  1.46s | valid accuracy    0.483
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.654
# | epoch   4 |    50/  231 batches | accuracy    0.720
# | epoch   4 |    75/  231 batches | accuracy    0.693
# | epoch   4 |   100/  231 batches | accuracy    0.693
# | epoch   4 |   125/  231 batches | accuracy    0.677
# | epoch   4 |   150/  231 batches | accuracy    0.693
# | epoch   4 |   175/  231 batches | accuracy    0.670
# | epoch   4 |   200/  231 batches | accuracy    0.772
# | epoch   4 |   225/  231 batches | accuracy    0.682
# -----------------------------------------------------------
# | end of epoch   4 | time:  1.79s | valid accuracy    0.609
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.692
# | epoch   5 |    50/  231 batches | accuracy    0.720
# | epoch   5 |    75/  231 batches | accuracy    0.725
# | epoch   5 |   100/  231 batches | accuracy    0.695
# | epoch   5 |   125/  231 batches | accuracy    0.713
# | epoch   5 |   150/  231 batches | accuracy    0.682
# | epoch   5 |   175/  231 batches | accuracy    0.713
# | epoch   5 |   200/  231 batches | accuracy    0.688
# | epoch   5 |   225/  231 batches | accuracy    0.685
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.18s | valid accuracy    0.580
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.683
# | epoch   6 |    50/  231 batches | accuracy    0.708
# | epoch   6 |    75/  231 batches | accuracy    0.690
# | epoch   6 |   100/  231 batches | accuracy    0.730
# | epoch   6 |   125/  231 batches | accuracy    0.713
# | epoch   6 |   150/  231 batches | accuracy    0.713
# | epoch   6 |   175/  231 batches | accuracy    0.713
# | epoch   6 |   200/  231 batches | accuracy    0.708
# | epoch   6 |   225/  231 batches | accuracy    0.745
# -----------------------------------------------------------
# | end of epoch   6 | time:  1.89s | valid accuracy    0.590
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.714
# | epoch   7 |    50/  231 batches | accuracy    0.708
# | epoch   7 |    75/  231 batches | accuracy    0.700
# | epoch   7 |   100/  231 batches | accuracy    0.743
# | epoch   7 |   125/  231 batches | accuracy    0.700
# | epoch   7 |   150/  231 batches | accuracy    0.718
# | epoch   7 |   175/  231 batches | accuracy    0.728
# | epoch   7 |   200/  231 batches | accuracy    0.708
# | epoch   7 |   225/  231 batches | accuracy    0.733
# -----------------------------------------------------------
# | end of epoch   7 | time:  2.25s | valid accuracy    0.592
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.712
# | epoch   8 |    50/  231 batches | accuracy    0.710
# | epoch   8 |    75/  231 batches | accuracy    0.703
# | epoch   8 |   100/  231 batches | accuracy    0.700
# | epoch   8 |   125/  231 batches | accuracy    0.700
# | epoch   8 |   150/  231 batches | accuracy    0.757
# | epoch   8 |   175/  231 batches | accuracy    0.708
# | epoch   8 |   200/  231 batches | accuracy    0.718
# | epoch   8 |   225/  231 batches | accuracy    0.725
# -----------------------------------------------------------
# | end of epoch   8 | time:  2.82s | valid accuracy    0.592
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.716
# | epoch   9 |    50/  231 batches | accuracy    0.710
# | epoch   9 |    75/  231 batches | accuracy    0.703
# | epoch   9 |   100/  231 batches | accuracy    0.708
# | epoch   9 |   125/  231 batches | accuracy    0.703
# | epoch   9 |   150/  231 batches | accuracy    0.748
# | epoch   9 |   175/  231 batches | accuracy    0.700
# | epoch   9 |   200/  231 batches | accuracy    0.715
# | epoch   9 |   225/  231 batches | accuracy    0.738
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.67s | valid accuracy    0.592
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.714
# | epoch  10 |    50/  231 batches | accuracy    0.720
# | epoch  10 |    75/  231 batches | accuracy    0.693
# | epoch  10 |   100/  231 batches | accuracy    0.695
# | epoch  10 |   125/  231 batches | accuracy    0.700
# | epoch  10 |   150/  231 batches | accuracy    0.718
# | epoch  10 |   175/  231 batches | accuracy    0.728
# | epoch  10 |   200/  231 batches | accuracy    0.705
# | epoch  10 |   225/  231 batches | accuracy    0.760
# -----------------------------------------------------------
# | end of epoch  10 | time:  2.21s | valid accuracy    0.592
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.373
# | epoch   1 |    50/  231 batches | accuracy    0.372
# | epoch   1 |    75/  231 batches | accuracy    0.415
# | epoch   1 |   100/  231 batches | accuracy    0.407
# | epoch   1 |   125/  231 batches | accuracy    0.407
# | epoch   1 |   150/  231 batches | accuracy    0.468
# | epoch   1 |   175/  231 batches | accuracy    0.522
# | epoch   1 |   200/  231 batches | accuracy    0.472
# | epoch   1 |   225/  231 batches | accuracy    0.510
# -----------------------------------------------------------
# | end of epoch   1 | time:  2.38s | valid accuracy    0.334
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.579
# | epoch   2 |    50/  231 batches | accuracy    0.517
# | epoch   2 |    75/  231 batches | accuracy    0.600
# | epoch   2 |   100/  231 batches | accuracy    0.598
# | epoch   2 |   125/  231 batches | accuracy    0.560
# | epoch   2 |   150/  231 batches | accuracy    0.527
# | epoch   2 |   175/  231 batches | accuracy    0.542
# | epoch   2 |   200/  231 batches | accuracy    0.595
# | epoch   2 |   225/  231 batches | accuracy    0.625
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.79s | valid accuracy    0.569
# ...
# | epoch   7 |    50/  231 batches | accuracy    0.710
# | epoch   7 |    75/  231 batches | accuracy    0.760
# | epoch   7 |   100/  231 batches | accuracy    0.743
# | epoch   7 |   125/  231 batches | accuracy    0.790
# | epoch   7 |   150/  231 batches | accuracy    0.782
# | epoch   7 |   175/  231 batches | accuracy    0.782
# | epoch   7 |   200/  231 batches | accuracy    0.752
# | epoch   7 |   225/  231 batches | accuracy    0.780
# -----------------------------------------------------------
# | end of epoch   7 | time:  1.88s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.764
# | epoch   8 |    50/  231 batches | accuracy    0.760
# | epoch   8 |    75/  231 batches | accuracy    0.733
# | epoch   8 |   100/  231 batches | accuracy    0.775
# | epoch   8 |   125/  231 batches | accuracy    0.757
# | epoch   8 |   150/  231 batches | accuracy    0.790
# | epoch   8 |   175/  231 batches | accuracy    0.745
# | epoch   8 |   200/  231 batches | accuracy    0.780
# | epoch   8 |   225/  231 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.60s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.764
# | epoch   9 |    50/  231 batches | accuracy    0.762
# | epoch   9 |    75/  231 batches | accuracy    0.765
# | epoch   9 |   100/  231 batches | accuracy    0.767
# | epoch   9 |   125/  231 batches | accuracy    0.725
# | epoch   9 |   150/  231 batches | accuracy    0.755
# | epoch   9 |   175/  231 batches | accuracy    0.775
# | epoch   9 |   200/  231 batches | accuracy    0.772
# | epoch   9 |   225/  231 batches | accuracy    0.770
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.57s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.781
# | epoch  10 |    50/  231 batches | accuracy    0.750
# | epoch  10 |    75/  231 batches | accuracy    0.757
# | epoch  10 |   100/  231 batches | accuracy    0.772
# | epoch  10 |   125/  231 batches | accuracy    0.720
# | epoch  10 |   150/  231 batches | accuracy    0.800
# | epoch  10 |   175/  231 batches | accuracy    0.767
# | epoch  10 |   200/  231 batches | accuracy    0.752
# | epoch  10 |   225/  231 batches | accuracy    0.765
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.59s | valid accuracy    0.627
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.305
# | epoch   1 |    50/  231 batches | accuracy    0.325
# | epoch   1 |    75/  231 batches | accuracy    0.440
# | epoch   1 |   100/  231 batches | accuracy    0.453
# | epoch   1 |   125/  231 batches | accuracy    0.407
# | epoch   1 |   150/  231 batches | accuracy    0.372
# | epoch   1 |   175/  231 batches | accuracy    0.435
# | epoch   1 |   200/  231 batches | accuracy    0.455
# | epoch   1 |   225/  231 batches | accuracy    0.470
# -----------------------------------------------------------
# | end of epoch   1 | time:  2.24s | valid accuracy    0.566
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.584
# | epoch   2 |    50/  231 batches | accuracy    0.510
# | epoch   2 |    75/  231 batches | accuracy    0.520
# | epoch   2 |   100/  231 batches | accuracy    0.560
# | epoch   2 |   125/  231 batches | accuracy    0.598
# | epoch   2 |   150/  231 batches | accuracy    0.557
# | epoch   2 |   175/  231 batches | accuracy    0.560
# | epoch   2 |   200/  231 batches | accuracy    0.557
# | epoch   2 |   225/  231 batches | accuracy    0.562
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.71s | valid accuracy    0.406
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.548
# | epoch   3 |    50/  231 batches | accuracy    0.645
# | epoch   3 |    75/  231 batches | accuracy    0.660
# | epoch   3 |   100/  231 batches | accuracy    0.623
# | epoch   3 |   125/  231 batches | accuracy    0.595
# | epoch   3 |   150/  231 batches | accuracy    0.640
# | epoch   3 |   175/  231 batches | accuracy    0.657
# | epoch   3 |   200/  231 batches | accuracy    0.688
# | epoch   3 |   225/  231 batches | accuracy    0.662
# -----------------------------------------------------------
# | end of epoch   3 | time:  2.17s | valid accuracy    0.607
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.654
# | epoch   4 |    50/  231 batches | accuracy    0.660
# | epoch   4 |    75/  231 batches | accuracy    0.657
# | epoch   4 |   100/  231 batches | accuracy    0.675
# | epoch   4 |   125/  231 batches | accuracy    0.650
# | epoch   4 |   150/  231 batches | accuracy    0.632
# | epoch   4 |   175/  231 batches | accuracy    0.652
# | epoch   4 |   200/  231 batches | accuracy    0.627
# | epoch   4 |   225/  231 batches | accuracy    0.662
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.02s | valid accuracy    0.603
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.671
# | epoch   5 |    50/  231 batches | accuracy    0.645
# | epoch   5 |    75/  231 batches | accuracy    0.667
# | epoch   5 |   100/  231 batches | accuracy    0.655
# | epoch   5 |   125/  231 batches | accuracy    0.685
# | epoch   5 |   150/  231 batches | accuracy    0.630
# | epoch   5 |   175/  231 batches | accuracy    0.675
# | epoch   5 |   200/  231 batches | accuracy    0.677
# | epoch   5 |   225/  231 batches | accuracy    0.650
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.39s | valid accuracy    0.587
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.692
# | epoch   6 |    50/  231 batches | accuracy    0.650
# | epoch   6 |    75/  231 batches | accuracy    0.695
# | epoch   6 |   100/  231 batches | accuracy    0.672
# | epoch   6 |   125/  231 batches | accuracy    0.632
# | epoch   6 |   150/  231 batches | accuracy    0.645
# | epoch   6 |   175/  231 batches | accuracy    0.647
# | epoch   6 |   200/  231 batches | accuracy    0.672
# | epoch   6 |   225/  231 batches | accuracy    0.677
# -----------------------------------------------------------
# | end of epoch   6 | time:  2.32s | valid accuracy    0.587
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.642
# | epoch   7 |    50/  231 batches | accuracy    0.667
# | epoch   7 |    75/  231 batches | accuracy    0.645
# | epoch   7 |   100/  231 batches | accuracy    0.693
# | epoch   7 |   125/  231 batches | accuracy    0.670
# | epoch   7 |   150/  231 batches | accuracy    0.642
# | epoch   7 |   175/  231 batches | accuracy    0.677
# | epoch   7 |   200/  231 batches | accuracy    0.650
# | epoch   7 |   225/  231 batches | accuracy    0.667
# -----------------------------------------------------------
# | end of epoch   7 | time:  2.58s | valid accuracy    0.586
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.673
# | epoch   8 |    50/  231 batches | accuracy    0.667
# | epoch   8 |    75/  231 batches | accuracy    0.685
# | epoch   8 |   100/  231 batches | accuracy    0.642
# | epoch   8 |   125/  231 batches | accuracy    0.662
# | epoch   8 |   150/  231 batches | accuracy    0.640
# | epoch   8 |   175/  231 batches | accuracy    0.682
# | epoch   8 |   200/  231 batches | accuracy    0.652
# | epoch   8 |   225/  231 batches | accuracy    0.647
# -----------------------------------------------------------
# | end of epoch   8 | time:  1.73s | valid accuracy    0.586
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.661
# | epoch   9 |    50/  231 batches | accuracy    0.655
# | epoch   9 |    75/  231 batches | accuracy    0.665
# | epoch   9 |   100/  231 batches | accuracy    0.667
# | epoch   9 |   125/  231 batches | accuracy    0.665
# | epoch   9 |   150/  231 batches | accuracy    0.630
# | epoch   9 |   175/  231 batches | accuracy    0.647
# | epoch   9 |   200/  231 batches | accuracy    0.670
# | epoch   9 |   225/  231 batches | accuracy    0.710
# -----------------------------------------------------------
# | end of epoch   9 | time:  1.71s | valid accuracy    0.586
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.627
# | epoch  10 |    50/  231 batches | accuracy    0.665
# | epoch  10 |    75/  231 batches | accuracy    0.657
# | epoch  10 |   100/  231 batches | accuracy    0.672
# | epoch  10 |   125/  231 batches | accuracy    0.667
# | epoch  10 |   150/  231 batches | accuracy    0.650
# | epoch  10 |   175/  231 batches | accuracy    0.642
# | epoch  10 |   200/  231 batches | accuracy    0.723
# | epoch  10 |   225/  231 batches | accuracy    0.680
# -----------------------------------------------------------
# | end of epoch  10 | time:  1.44s | valid accuracy    0.586
# -----------------------------------------------------------
# | epoch   1 |    25/  231 batches | accuracy    0.296
# | epoch   1 |    50/  231 batches | accuracy    0.335
# | epoch   1 |    75/  231 batches | accuracy    0.475
# | epoch   1 |   100/  231 batches | accuracy    0.480
# | epoch   1 |   125/  231 batches | accuracy    0.455
# | epoch   1 |   150/  231 batches | accuracy    0.453
# | epoch   1 |   175/  231 batches | accuracy    0.500
# | epoch   1 |   200/  231 batches | accuracy    0.505
# | epoch   1 |   225/  231 batches | accuracy    0.515
# -----------------------------------------------------------
# | end of epoch   1 | time:  1.58s | valid accuracy    0.555
# -----------------------------------------------------------
# | epoch   2 |    25/  231 batches | accuracy    0.555
# | epoch   2 |    50/  231 batches | accuracy    0.527
# | epoch   2 |    75/  231 batches | accuracy    0.580
# | epoch   2 |   100/  231 batches | accuracy    0.547
# | epoch   2 |   125/  231 batches | accuracy    0.585
# | epoch   2 |   150/  231 batches | accuracy    0.575
# | epoch   2 |   175/  231 batches | accuracy    0.593
# | epoch   2 |   200/  231 batches | accuracy    0.615
# | epoch   2 |   225/  231 batches | accuracy    0.552
# -----------------------------------------------------------
# | end of epoch   2 | time:  1.50s | valid accuracy    0.580
# -----------------------------------------------------------
# | epoch   3 |    25/  231 batches | accuracy    0.589
# | epoch   3 |    50/  231 batches | accuracy    0.662
# | epoch   3 |    75/  231 batches | accuracy    0.600
# | epoch   3 |   100/  231 batches | accuracy    0.627
# | epoch   3 |   125/  231 batches | accuracy    0.640
# | epoch   3 |   150/  231 batches | accuracy    0.693
# | epoch   3 |   175/  231 batches | accuracy    0.615
# | epoch   3 |   200/  231 batches | accuracy    0.675
# | epoch   3 |   225/  231 batches | accuracy    0.650
# -----------------------------------------------------------
# | end of epoch   3 | time:  1.66s | valid accuracy    0.500
# -----------------------------------------------------------
# | epoch   4 |    25/  231 batches | accuracy    0.644
# | epoch   4 |    50/  231 batches | accuracy    0.688
# | epoch   4 |    75/  231 batches | accuracy    0.740
# | epoch   4 |   100/  231 batches | accuracy    0.780
# | epoch   4 |   125/  231 batches | accuracy    0.672
# | epoch   4 |   150/  231 batches | accuracy    0.708
# | epoch   4 |   175/  231 batches | accuracy    0.665
# | epoch   4 |   200/  231 batches | accuracy    0.710
# | epoch   4 |   225/  231 batches | accuracy    0.672
# -----------------------------------------------------------
# | end of epoch   4 | time:  2.46s | valid accuracy    0.621
# -----------------------------------------------------------
# | epoch   5 |    25/  231 batches | accuracy    0.745
# | epoch   5 |    50/  231 batches | accuracy    0.698
# | epoch   5 |    75/  231 batches | accuracy    0.672
# | epoch   5 |   100/  231 batches | accuracy    0.752
# | epoch   5 |   125/  231 batches | accuracy    0.710
# | epoch   5 |   150/  231 batches | accuracy    0.705
# | epoch   5 |   175/  231 batches | accuracy    0.745
# | epoch   5 |   200/  231 batches | accuracy    0.703
# | epoch   5 |   225/  231 batches | accuracy    0.672
# -----------------------------------------------------------
# | end of epoch   5 | time:  2.54s | valid accuracy    0.626
# -----------------------------------------------------------
# | epoch   6 |    25/  231 batches | accuracy    0.716
# | epoch   6 |    50/  231 batches | accuracy    0.733
# | epoch   6 |    75/  231 batches | accuracy    0.695
# | epoch   6 |   100/  231 batches | accuracy    0.750
# | epoch   6 |   125/  231 batches | accuracy    0.705
# | epoch   6 |   150/  231 batches | accuracy    0.725
# | epoch   6 |   175/  231 batches | accuracy    0.700
# | epoch   6 |   200/  231 batches | accuracy    0.718
# | epoch   6 |   225/  231 batches | accuracy    0.695
# -----------------------------------------------------------
# | end of epoch   6 | time:  2.77s | valid accuracy    0.626
# -----------------------------------------------------------
# | epoch   7 |    25/  231 batches | accuracy    0.716
# | epoch   7 |    50/  231 batches | accuracy    0.725
# | epoch   7 |    75/  231 batches | accuracy    0.735
# | epoch   7 |   100/  231 batches | accuracy    0.688
# | epoch   7 |   125/  231 batches | accuracy    0.755
# | epoch   7 |   150/  231 batches | accuracy    0.760
# | epoch   7 |   175/  231 batches | accuracy    0.718
# | epoch   7 |   200/  231 batches | accuracy    0.710
# | epoch   7 |   225/  231 batches | accuracy    0.715
# -----------------------------------------------------------
# | end of epoch   7 | time:  2.79s | valid accuracy    0.594
# -----------------------------------------------------------
# | epoch   8 |    25/  231 batches | accuracy    0.745
# | epoch   8 |    50/  231 batches | accuracy    0.700
# | epoch   8 |    75/  231 batches | accuracy    0.708
# | epoch   8 |   100/  231 batches | accuracy    0.698
# | epoch   8 |   125/  231 batches | accuracy    0.738
# | epoch   8 |   150/  231 batches | accuracy    0.715
# | epoch   8 |   175/  231 batches | accuracy    0.713
# | epoch   8 |   200/  231 batches | accuracy    0.710
# | epoch   8 |   225/  231 batches | accuracy    0.735
# -----------------------------------------------------------
# | end of epoch   8 | time:  2.29s | valid accuracy    0.617
# -----------------------------------------------------------
# | epoch   9 |    25/  231 batches | accuracy    0.726
# | epoch   9 |    50/  231 batches | accuracy    0.767
# | epoch   9 |    75/  231 batches | accuracy    0.700
# | epoch   9 |   100/  231 batches | accuracy    0.750
# | epoch   9 |   125/  231 batches | accuracy    0.718
# | epoch   9 |   150/  231 batches | accuracy    0.755
# | epoch   9 |   175/  231 batches | accuracy    0.777
# | epoch   9 |   200/  231 batches | accuracy    0.680
# | epoch   9 |   225/  231 batches | accuracy    0.677
# -----------------------------------------------------------
# | end of epoch   9 | time:  2.14s | valid accuracy    0.618
# -----------------------------------------------------------
# | epoch  10 |    25/  231 batches | accuracy    0.709
# | epoch  10 |    50/  231 batches | accuracy    0.698
# | epoch  10 |    75/  231 batches | accuracy    0.765
# | epoch  10 |   100/  231 batches | accuracy    0.713
# | epoch  10 |   125/  231 batches | accuracy    0.735
# | epoch  10 |   150/  231 batches | accuracy    0.708
# | epoch  10 |   175/  231 batches | accuracy    0.757
# | epoch  10 |   200/  231 batches | accuracy    0.738
# | epoch  10 |   225/  231 batches | accuracy    0.748
# -----------------------------------------------------------
# | end of epoch  10 | time:  2.38s | valid accuracy    0.618
# -----------------------------------------------------------

# %%
# plot accuracies
import matplotlib.pyplot as plt
plt.plot(sorted(accuracies), label='Model accuracies')
plt.axhline(y=0.33, color='r', linestyle='-', label='Random guess')
plt.axhline(y=sum(accuracies)/runs, color='orange', linestyle='-', label='Mean accuracy')
plt.ylabel('Model Accuracies')
plt.title(f"Accuracies of {runs} individual train-evaluation runs")
plt.legend(loc="lower right", borderaxespad=0)
plt.savefig(PATH_PERFORMANCE_GRAPH)
plt.show()

# %% [markdown]
# Test on a random sample
# ---------------------

# %%
opinion_label = {0: "-",
                 1: "o",
                 2: "+"}

def predict(text, text_pipeline):
    with torch.no_grad():
        text = torch.tensor(text_pipeline(text))
        output = model(text, torch.tensor([0]))
        return output.argmax(1).item()

ex_text_str = "Alle können jetzt durch diesen Lockdown kom­men, weil die Coronakurzarbeit dafür adaptiert wurde."

print("The opinion is %s" %opinion_label[predict(ex_text_str, text_pipeline)])
